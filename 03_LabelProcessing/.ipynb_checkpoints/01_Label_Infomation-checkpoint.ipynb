# %%
import pandas as pd
import numpy as np
from matplotlib import pyplot as plt
import re
import os
import shutil
# pd.set_option("max_columns",0)

# %%
classification = pd.read_csv('../02_ImageProcessing/seal_pct_color.csv', index_col=0)
classification
# Out:
#              filename    x    y    size  color_area  pct_color
# 0     0000_蒋风白写生记.png  500  496  248000       96013   0.387149
# 1         0001_韦之.png  740  529  391460      134905   0.344620
# 2          0002_揆.png  337  327  110199       38554   0.349858
# 3       0003_塞北绕春.png  592  582  344544      201401   0.584544
# 4       0004_谭延闿印.png  533  518  276094      126318   0.457518
# ...               ...  ...  ...     ...         ...        ...
# 9991      9995_抱石.png  373  193   71989       26715   0.371098
# 9992     9996_秋水亭.png  882  343  302526       85907   0.283966
# 9993      9997_徵明.png  493  238  117334       38647   0.329376
# 9994       9998_项.png  346  342  118332       30982   0.261823
# 9995    9999_返老还童.png  536  517  277112      146496   0.528653
#
# [9996 rows x 6 columns]

# %% [markdown]
# ## classify_owner

# %%
def classify_owner(df):
    seal_all = pd.read_csv('../01_API_DataCollection/seal_all.csv', index_col=0)
    seal_all.reset_index(inplace=True)
    seal_all.rename({'index':'number'},axis=1,inplace=True)
    df['number'] = df['filename'].apply(lambda x: int(x[:4]))
    df = df.merge(right=seal_all[['number','ownerOfSeal','labelChs','labelCht']], on=["number"], how='left')
    df.rename({'ownerOfSeal':'classify_owner'},axis=1,inplace=True)
    return df

# %% [markdown]
# ## Clean the label

# %%
def label_clean(row, column_name):
    column = column_name
    if row[column][-1].isdigit() == True:
        return row[column][:-1]
    else:
        return row[column]
    
def brackets_remover(row, column_name):
    column = column_name
    s = row[column]
    start = '('
    end = ')'
    s_replace = s[s.find(start)+len(start)-1:s.rfind(end)+1]
    s = s.replace(s_replace,'')
    return s

def clean_all_label(df, column_name):
    column = column_name
    df[column] = df[column].apply(lambda x: x.replace('"',''))
    df[column] = df[column].apply(lambda x: x.replace('“',''))
    df[column] = df[column].apply(lambda x: x.replace('”',''))
    df[column] = df[column].apply(lambda x: x.replace('（','('))
    df[column] = df[column].apply(lambda x: x.replace('）',')'))
    df[column] = df.apply(lambda row: brackets_remover(row, column), axis=1)

    df[column] = df.apply(lambda row: label_clean(row, column), axis=1)
    df[column] = df.apply(lambda row: label_clean(row, column), axis=1)
    df[column] = df.apply(lambda row: label_clean(row, column), axis=1)
    
    return df

# %%
classification = classify_owner(classification)
classification = clean_all_label(classification, 'labelChs')
classification = clean_all_label(classification, 'labelCht')
classification
# Out:
#              filename    x    y    size  color_area  pct_color  number  \
# 0     0000_蒋风白写生记.png  500  496  248000       96013   0.387149       0
# 1         0001_韦之.png  740  529  391460      134905   0.344620       1
# 2          0002_揆.png  337  327  110199       38554   0.349858       2
# 3       0003_塞北绕春.png  592  582  344544      201401   0.584544       3
# 4       0004_谭延闿印.png  533  518  276094      126318   0.457518       4
# ...               ...  ...  ...     ...         ...        ...     ...
# 9991      9995_抱石.png  373  193   71989       26715   0.371098    9995
# 9992     9996_秋水亭.png  882  343  302526       85907   0.283966    9996
# 9993      9997_徵明.png  493  238  117334       38647   0.329376    9997
# 9994       9998_项.png  346  342  118332       30982   0.261823    9998
# 9995    9999_返老还童.png  536  517  277112      146496   0.528653    9999
#
#      classify_owner labelChs labelCht
# 0               蒋风白   蒋风白写生记   蔣風白寫生記
# ...

# %% [markdown]
# ## classify_content

# %% [markdown]
# ### *name*

# %%
def content_name(row):
    owner = str(row['classify_owner'])
    label = str(row['labelChs'])
    if owner == label:
        return '姓名'
    elif owner+'印' == label:
        return '印'
    elif owner+'章' == label:
        return '章'    
    elif owner+'之印' == label:
        return '之印'
    elif owner+'之章' == label:
        return '之章'   
    else:
        return '无'

# %% [markdown]
# ### *collection*

# %%
def content_collection(row):
    label = str(row['labelChs'])
    if '收藏' in label \
           or '考藏' in label \
           or '珍藏' in label \
           or '鉴藏' in label \
           or '藏书' in label \
           or '珍玩' in label \
           or '秘玩' in label \
           or '珍秘' in label \
           or '书画' in label \
           or '图书' in label \
           or '金石' in label:
        return '收藏类'
    elif '考订' in label \
           or '审定' in label \
           or '鉴定' in label:
        return '校订类'
    elif '鉴赏' in label \
           or '珍赏' in label \
           or '清赏' in label \
           or '心赏' in label \
           or '读过' in label \
           or '过目' in label \
           or '过眼' in label \
           or '经眼' in label \
           or '眼福' in label:
        return '鉴赏类'
    else:
        return '无'

# %% [markdown]
# ### *book*

# %%
def content_book(row):
    label = str(row['labelChs'])
    if '启事' in label \
          or '白事' in label \
          or '白笺' in label \
          or '言事' in label \
          or '信印' in label \
          or '顿首' in label:
        return '书简印'
    else:
        return '无'

# %% [markdown]
# ### *gallery*

# %%
def content_gallery(row):
    label = str(row['labelChs'])
    if label[-1]=='馆' \
          or label[-1]=='斋' \
          or label[-1]=='室' \
          or label[-1]=='堂' \
          or label[-1]=='楼' \
          or label[-1]=='房' \
          or label[-1]=='庵' \
          or label[-2:]=='馆印' \
          or label[-2:]=='斋印' \
          or label[-2:]=='室印' \
          or label[-2:]=='堂印' \
          or label[-2:]=='楼印' \
          or label[-2:]=='房印' \
          or label[-2:]=='庵印': 
        return '斋馆别号印'
    else:
        return '无'

# %% [markdown]
# ### *ALL*

# %%
def classify_content(row):
    if row['content_name'] != '无':
        return '姓名印'
    elif row['content_collection'] != '无':
        return '收藏鉴赏印'
    elif row['content_book'] != '无':
        return '书简印'
    elif row['content_gallery'] != '无':
        return '斋馆别号印'
    else:
        return '无'

# %%
classification['content_name'] = classification.apply(lambda row: content_name(row), axis=1)
classification['content_collection'] = classification.apply(lambda row: content_collection(row), axis=1)
classification['content_book'] = classification.apply(lambda row: content_book(row), axis=1)
classification['content_gallery'] = classification.apply(lambda row: content_gallery(row), axis=1)

classification['classify_content'] = classification.apply(lambda row: classify_content(row), axis=1)
# classification.head(5)

# %% [markdown]
# ### *MOVE*

# %%
for fname in os.listdir("../classification/content"):
    input_path = "../classification/content/" + fname
    
    name = classification[classification['classify_content']=='姓名印']
    collection = classification[classification['classify_content']=='收藏鉴赏印']
    book = classification[classification['classify_content']=='书简印']
    gallery = classification[classification['classify_content']=='斋馆别号印']
    
    if fname[-3:] == 'png' and fname in name['filename'].unique().tolist():
        end_path = "../classification/content/name/" + fname
        shutil.move(input_path, end_path)
    if fname[-3:] == 'png' and fname in collection['filename'].unique().tolist():
        end_path = "../classification/content/collection/" + fname
        shutil.move(input_path, end_path)
    if fname[-3:] == 'png' and fname in book['filename'].unique().tolist():
        end_path = "../classification/content/book/" + fname
        shutil.move(input_path, end_path)
    if fname[-3:] == 'png' and fname in gallery['filename'].unique().tolist():
        end_path = "../classification/content/gallery/" + fname
        shutil.move(input_path, end_path)
print('finish')
# Out:
# finish

# %%
# classification

# %% [markdown]
# ## classify_graphics

# %%
graphics = []

for filename in os.listdir("../classification/graphics"):
    graphics.append(filename)

def classify_graphics(row):
    filename = row['filename']
    if filename in graphics:
        return '图画印'
    else:
        return '无'

# %% [markdown]
# ## classify_withsides

# %%
withsides = []

for filename in os.listdir("../classification/withsides"):
    withsides.append(filename)

def classify_withsides(row):
    filename = row['filename']
    if filename in withsides:
        return '边款'
    else:
        return '无'

# %% [markdown]
# ## classify_border

# %%
border_special = []
border_without = []
border_jing = []
border_ya = []
border_kou = []
border_koukou = []
border_koukoukou = []
border_yuan = []
border_yuanplusfang = []
border_ri = []
border_ripluskou = []
border_ririri = []
border_tian = []

for filename in os.listdir("../classification/border/special"):
    border_special.append(filename)
for filename in os.listdir("../classification/border/without"):
    border_without.append(filename)
for filename in os.listdir("../classification/border/井"):
    border_jing.append(filename)
for filename in os.listdir("../classification/border/亚"):
    border_ya.append(filename)
for filename in os.listdir("../classification/border/口"):
    border_kou.append(filename)
for filename in os.listdir("../classification/border/口口"):
    border_koukou.append(filename)
for filename in os.listdir("../classification/border/口口口"):
    border_koukoukou.append(filename)
for filename in os.listdir("../classification/border/圆"):
    border_yuan.append(filename)
for filename in os.listdir("../classification/border/圆+方"):
    border_yuanplusfang.append(filename)
for filename in os.listdir("../classification/border/日"):
    border_ri.append(filename)
for filename in os.listdir("../classification/border/日+口"):
    border_ripluskou.append(filename)
for filename in os.listdir("../classification/border/日日日"):
    border_ririri.append(filename)
for filename in os.listdir("../classification/border/田"):
    border_tian.append(filename)

def classify_border(row):
    filename = row['filename']
    if filename in border_special:
        return '特殊'
    elif filename in border_without:
        return '无'
    elif filename in border_jing:
        return '井'    
    elif filename in border_ya:
        return '亚'
    elif filename in border_kou:
        return '口'  
    elif filename in border_koukou:
        return '口口'
    elif filename in border_koukoukou:
        return '口口口'    
    elif filename in border_yuan:
        return '圆'
    elif filename in border_yuanplusfang:
        return '圆+方'  
    elif filename in border_ri:
        return '日'    
    elif filename in border_ripluskou:
        return '日+口'
    elif filename in border_ririri:
        return '日日日'  
    elif filename in border_tian:
        return '田'    
    else:
        return '无'

# %% [markdown]
# ## classify_length

# %%
def classify_length(row):
    length = len(row['labelChs']) 
    if length < 10:
        return length
    elif length >= 10:
        return '>=10'
    else:
        return '无'

# %% [markdown]
# ## classify_shape

# %%
shape_circle = []
shape_ellipse = []
shape_triangle = []
shape_rectangle = []
shape_square = []
shape_multiple = []
shape_others = []

for filename in os.listdir("../classification/shape/0_circle"):
    shape_circle.append(filename)
for filename in os.listdir("../classification/shape/0_ellipse"):
    shape_ellipse.append(filename)
for filename in os.listdir("../classification/shape/3_triangle"):
    shape_triangle.append(filename)
for filename in os.listdir("../classification/shape/4_rectangle"):
    shape_rectangle.append(filename)
for filename in os.listdir("../classification/shape/4_square"):
    shape_square.append(filename)
for filename in os.listdir("../classification/shape/multiple"):
    shape_multiple.append(filename)
for filename in os.listdir("../classification/shape/others"):
    shape_others.append(filename)

def classify_shape(row):
    filename = row['filename']
    if filename in shape_circle:
        return '圆形'
    elif filename in shape_ellipse:
        return '椭圆形'
    elif filename in shape_triangle:
        return '三角形'    
    elif filename in shape_rectangle:
        return '长方形'
    elif filename in shape_square:
        return '方形'  
    elif filename in shape_multiple:
        return '多个'
    elif filename in shape_others:
        return '其他'    
    else:
        return '无'

# %% [markdown]
# ## classify_yinwen

# %%
yinwen_redletters = []
yinwen_whiteletters = []
yinwen_others = []

for filename in os.listdir("../classification/yinwen/red_letter"):
    yinwen_redletters.append(filename)
for filename in os.listdir("../classification/yinwen/white_letter"):
    yinwen_whiteletters.append(filename)
for filename in os.listdir("../classification/yinwen/others"):
    yinwen_others.append(filename)

def classify_yinwen(row):
    filename = row['filename']
    if filename in yinwen_redletters:
        return '朱文'
    elif filename in yinwen_whiteletters:
        return '白文'
    elif filename in yinwen_others:
        return '朱白相间文'  
    else:
        return '无'

# %% [markdown]
# # ---RUN---

# %%
classification['数量'] = 1
classification["序号"] = classification["number"]
classification["文件名"] = classification["filename"]
classification["简体"] = classification["labelChs"]
classification["繁体"] = classification["labelCht"]

classification["img_x"] = classification["y"]
classification["img_y"] = classification["x"]
classification["朱色比例"] = classification["pct_color"]
classification["朱色比例"] = classification["朱色比例"].apply(lambda x:round(x,2))

classification["作者_细节"] = classification["classify_owner"]

onwer_s = classification.groupby(by=["作者_细节"]).agg({"数量":"sum"}).reset_index()
onwer_list = onwer_s[onwer_s['数量']>100]['作者_细节'].tolist()

def classify_zh(row):
    owner = row['作者_细节']
    if owner in onwer_list:
        return owner
    else:
        return '其他'
classification["作者"] = classification.apply(lambda row: classify_zh(row), axis=1)

classification["图画印"] = classification.apply(lambda row: classify_graphics(row), axis=1)
classification["边款"] = classification.apply(lambda row: classify_withsides(row), axis=1)
classification['边框'] = classification.apply(lambda row: classify_border(row), axis=1)
classification['印文字数'] = classification.apply(lambda row: classify_length(row), axis=1)
classification['印形'] = classification.apply(lambda row: classify_shape(row), axis=1)
classification['印文'] = classification.apply(lambda row: classify_yinwen(row), axis=1)
classification['印面内容'] = classification.apply(lambda row: classify_content(row), axis=1)
classification['--姓名印'] = classification['content_name']
classification['--收藏鉴赏印'] = classification['content_collection']
classification['--书简印'] = classification['content_book']
classification['--斋馆别号印'] = classification['content_gallery']

print(classification.shape)
classification.iloc[:,-21:]
# Out:
# (9996, 36)
#       数量    序号              文件名      简体      繁体  img_x  img_y  朱色比例 作者_细节  \
# 0      1     0  0000_蒋风白写生记.png  蒋风白写生记  蔣風白寫生記    496    500  0.39   蒋风白
# 1      1     1      0001_韦之.png      韦之      韋之    529    740  0.34   高其佩
# 2      1     2       0002_揆.png       揆       揆    327    337  0.35   程正揆
# 3      1     3    0003_塞北绕春.png    塞北绕春    塞北繞春    582    592  0.58   榭稚柳
# 4      1     4    0004_谭延闿印.png    谭延闿印    譚延闿印    518    533  0.46   谭延闿
# ...   ..   ...              ...     ...     ...    ...    ...   ...   ...
# 9991   1  9995      9995_抱石.png      抱石      抱石    193    373  0.37   傅抱石
# 9992   1  9996     9996_秋水亭.png     秋水亭     秋水亭    343    882  0.28   莫是龙
# 9993   1  9997      9997_徵明.png      徵明      徵明    238    493  0.33   文徵明
# 9994   1  9998       9998_项.png       项       項    342    346  0.26   项圣谟
# 9995   1  9999    9999_返老还童.png    返老还童    返老還童    517    536  0.53   童大年
#
# ...

# %%
classification.iloc[:,-21:].to_csv('classification.csv')
print('-finish-'*10)
classification.iloc[:,-21:].dtypes
# Out:
# -finish--finish--finish--finish--finish--finish--finish--finish--finish--finish-
# 数量           int64
# 序号           int64
# 文件名         object
# 简体          object
# 繁体          object
# img_x        int64
# img_y        int64
# 朱色比例       float64
# 作者_细节       object
# 作者          object
# 图画印         object
# 边款          object
# 边框          object
# 印文字数        object
# 印形          object
# 印文          object
# 印面内容        object
# --姓名印       object
# --收藏鉴赏印     object
# --书简印       object
# --斋馆别号印     object
# dtype: object

# %%
### Gives positional information of the missing values
# import missingno as msno
# msno.matrix(classification)

# %%
onwer_s = classification.groupby(by=["作者"]).agg({"数量":"sum"}).reset_index()
onwer_s[onwer_s['数量']>100]['作者'].tolist()
# Out:
# ['余任天', '其他', '吴昌硕', '寿石工', '弘旿', '张大千', '榭稚柳', '陈半丁', '陈衡恪', '齐白石']

# %%
import zhconv
def Fun(s):
    return zhconv.convert(s, 'zh-cn')

# %%
sealOwner_froms = classification[['作者_细节']].drop_duplicates().reset_index(drop=True)
sealOwner_froms.rename({'作者_细节':'作者'},axis=1,inplace=True)
sealOwner_froms
# Out:
#       作者
# 0    蒋风白
# 1    高其佩
# 2    程正揆
# 3    榭稚柳
# 4    谭延闿
# ..   ...
# 432   陈鱣
# 433  瞿绍基
# 434   卢址
# 435   丁申
# 436   吴城
#
# [437 rows x 1 columns]

# %%
sealOwner_all = pd.read_csv('../01_API_DataCollection/sealOwner_all.csv', index_col=0)
sealOwner_all['作者'] = sealOwner_all['name'].apply(lambda x: Fun(x))
sealOwner_all.rename({'birthday':'生年','deathday':'卒年','description':'介绍',},axis=1,inplace=True)
sealOwner_all
# Out:
#             生年 name                                                 介绍  \
# 0         1832   丁丙  丁丙（1832—1899）字嘉魚，别字松生，清杭州錢塘（今杭州）人，與其兄丁申共同經營八千卷...
# 1         1879   丁仁  清末民国篆刻家。八千卷楼楼主丁丙从孙。幼承庭训，喜好金石书画，嗜印成癖，抚拓无虚日，光绪三十...
# 2         1878  丁佛言  清末民国书法家、古文字学家。县庠生员、补廪生。光绪三十一年（1905）官费东渡入东京法政大学...
# 3         1695   丁敬  丁敬（1695—1765）清代书画家、篆刻家。字敬身，号钝丁、砚林，别号龙泓山人、孤云、石叟...
# 4         1827  丁文蔚  清书画家。官至福建长乐知县。擅书画，尤长花卉，秀雅古逸。其篆隶书法深得汉人古拙之趣。擅刻竹，...
# ..         ...  ...                                                ...
# 454       1565   黃鉞  清大臣、画家、篆刻家。乾隆五十五年（1790）进士，授户部主事，与和坤意左，告假回芜。掌教皖...
# 455  1747.6.30   黎簡  黎简（1747年6月30日～1799年12月3日）字简民，一字未裁。号二樵，又号石鼎道人、百...
# 456       1907  齊燕銘  学者、书法篆刻家。自幼勤奋好学，对金石篆刻、书法、京戏均有兴趣。1924年入中国大学预科读书...
# 457       1864  齊白石  近代画家。出身贫寒，做过农活，跟随叔祖父学过木匠，改学雕花木工。从民间画工入手，曾习古人真迹...
# 458       1618   龔賢  龚贤（1618—1689年），又名岂贤,字半千,又字野遗,、岂贤,号半亩,又号柴丈人，江苏昆...
#
#              卒年                                                uri   作者
# ...

# %%
onwer_final = sealOwner_froms.merge(right=sealOwner_all[['作者','生年','卒年','介绍']], on=["作者"], how='outer')
onwer_final.to_csv('onwer_final.csv')
onwer_final
# Out:
#       作者    生年    卒年                                                 介绍
# 0    蒋风白  1915  2004  现代书画篆刻家。1930年考入国立杭州艺专，得潘天寿大师亲授。1938年任国立四川中学高中部...
# 1    高其佩  1660  1734  清官吏、画家。指画开山祖。康熙三十三年（1694），由祖荫出任姚州牧，次年转任虞部郎中。康熙...
# 2    程正揆  1604  1676  程正揆（1604～1676）中国明末清初画家，书法家。字端伯，号鞠陵，别号清溪道人。湖北孝感...
# 3    榭稚柳  1910  1997  现代书画家、鉴藏家。早年从钱振学画。1943年任中央大学艺术系教授。1942年与张大千赴敦煌...
# 4    谭延闿   NaN   NaN                                                NaN
# ..   ...   ...   ...                                                ...
# 477   陈鳣   NaN   NaN  陳鱣（1753—1817）字仲魚，號簡莊，浙江海寧人，嘉慶三年（1798）舉人。陳鱣性嗜典籍...
# 478  高凤翰  1683  1743  高凤翰（1683年～1749年），胶州大行高氏二股十一世，清代书法家、画家、篆刻家；山东胶州...
# 479   黄吕   NaN   NaN  清乾隆间书法篆刻家。黄白山（起溟）之子，工诗文，擅书法，隶学汉人，行草学晋人，晚年益朴茂，求...
# 480   黄易  1952   NaN  黄易（原名黄祖强）（1952-2017），1952年出生于香港，毕业于香港中文大学，中国香港...
# 481  黄景仁  1749  1783  黄景仁（1749年—1783年），字汉镛，一字仲则，号鹿菲子，常州府武进县（今江苏省常州市武...
#
# [482 rows x 4 columns]

# %%
onwer_final[onwer_final['生年']=='1915']['作者'].tolist()
# Out:
# ['蒋风白', '王梦石', '白雪石']

# %%
df_1 = onwer_final[onwer_final['作者']=='高其佩'].T.reset_index()
df_1.rename({'index':'属性',1:'印章（左）'},axis=1,inplace=True)
df_2 = onwer_final[onwer_final['作者']=='高其佩'].T.reset_index()
df_2.rename({'index':'属性',1:'印章（右）'},axis=1,inplace=True)
df = df_1.merge(right=df_2, on=["属性"])
df
# Out:
#    属性                                              印章（左）  \
# 0  作者                                                高其佩
# 1  生年                                               1660
# 2  卒年                                               1734
# 3  介绍  清官吏、画家。指画开山祖。康熙三十三年（1694），由祖荫出任姚州牧，次年转任虞部郎中。康熙...
#
#                                                印章（右）
# 0                                                高其佩
# 1                                               1660
# 2                                               1734
# 3  清官吏、画家。指画开山祖。康熙三十三年（1694），由祖荫出任姚州牧，次年转任虞部郎中。康熙...

# %%
classification[classification['序号']==9998]['作者_细节'].tolist()[0]
# Out:
# '项圣谟'

# %%
# o1 = classification["作者_细节"].unique().tolist()
# o2 = sealOwner_all["name"].unique().tolist()
# o3 = sealOwner_all["name_cn"].unique().tolist()
# i = 0
# for o in o1:
#     if (o in o2) == False and (o in o3) == False:
#         i += 1
#         print(o)
# print(i)

# %%
# zhconv.convert("鄒先生", 'zh-cn')
